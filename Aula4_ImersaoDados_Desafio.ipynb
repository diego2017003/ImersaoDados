# %% [markdown]
# <a href="https://colab.research.google.com/github/diego2017003/ImersaoDados/blob/main/Aula4_ImersaoDados_Desafio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Aula 04
#
# ###Desafio 01: Encontrar o top 10, das ações do MOA (inibidor, agonista...)
#
# ###Desafio 02: Criar a coluna eh_controle para quando na linha tratamento == com_controle
#
# ###Desafio 03: Criar três colunas para indicar o tempo 24, 48, 72
#
# ###Desafio 04: Estudar sobre combinações de DF https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
#
#
# ###Desafio 05: Fazer análise mais detalhada considerando tempo e dose, para comparar as distribuições (Escolher uma droga e comparar com controle)
#
# ###Desafio 06: Descobrir se tem algum composto que dependendo da configuração do experimento, ativa ou não ativa algum MOA
#
# ###Desafio 07: Descobrir se tem algum composto que dependendo da configuração do experimento, ativa MOAs diferentes
#
#
# ###Desafio 08: Resumo do que você aprendeu com os dados

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados = dados.rename(columns=lambda x: "".join(x.split("-")))
dados.rename(columns={'droga': 'composto'}, inplace=True)
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
#modificações feitas na aula sobre as tabelas
dados_resultados['n_moa'] = dados_resultados.drop('id', axis=1).sum(axis=1)
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0)
#merge de dados com dados_resultados
dados_combinados = pd.merge(dados, dados_resultados[['id','n_moa', 'ativo_moa']], on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...     c98     c99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176   13.0       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371    0.0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931   27.0       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154    0.0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125   13.0       True
#
# [5 rows x 879 columns]

# %% [markdown]
# #Desafio 1
# ---

# %%
import plotly.express as px 
contagem_moa = dados_resultados.drop(['id','n_moa','ativo_moa'], axis=1).sum().sort_values(ascending=False).T
cm = contagem_moa.T.groupby([s.split('_')[-1] for s in contagem_moa.T.index.values]).sum().T.sort_values(ascending=False)
print(cm[0:10])
px.bar(x=list(cm[:10].keys()),y=cm[:10].values,title="top 10 MOA",orientation='v',color_discrete_sequence=px.colors.sequential.RdBu)
#Top 10 dos resultados de cada MOA
# Out:
# inhibitor            9693
# antagonist           3449
# agonist              2330
# blocker               323
# agent                 150
# activator             115
# local                  80
# immunosuppressant      73
# anti-inflammatory      73
# antioxidant            73
# dtype: int64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f5fcdd86-c38b-4646-b56b-8b7e869be43e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f5fcdd86-c38b-4646-b56b-8b7e869be43e")) {
#                     Plotly.newPlot(
#                         'f5fcdd86-c38b-4646-b56b-8b7e869be43e',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}", "legendgroup": "", "marker": {"color": "rgb(103,0,31)"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["inhibitor", "antagonist", "agonist", "blocker", "agent", "activator", "local", "immunosuppressant", "anti-inflammatory", "antioxidant"], "xaxis": "x", "y": [9693, 3449, 2330, 323, 150, 115, 80, 73, 73, 73], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
contagem_moa2 = dados_resultados.drop(['id','n_moa','ativo_moa'], axis=1).sum().sort_values(ascending=False).T
cm2 = contagem_moa.rename(index=lambda x: x.split("_")[-1]).index.value_counts()
print(cm2[:10])
px.bar(x=list(cm2[:10].keys()),y=cm2[:10].values,title="top 10 MOA ocorrências nas classes",orientation='v',color_discrete_sequence=px.colors.sequential.RdBu)
#Top 10 de ocorrências de cada MOA na Tabela
# Out:
# inhibitor            112
# antagonist            32
# agonist               28
# activator              5
# agent                  3
# blocker                2
# antihistamine          1
# anti-inflammatory      1
# local                  1
# antioxidant            1
# dtype: int64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="87f81524-a840-4169-b597-d67d35268716" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("87f81524-a840-4169-b597-d67d35268716")) {
#                     Plotly.newPlot(
#                         '87f81524-a840-4169-b597-d67d35268716',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}", "legendgroup": "", "marker": {"color": "rgb(103,0,31)"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["inhibitor", "antagonist", "agonist", "activator", "agent", "blocker", "antihistamine", "anti-inflammatory", "local", "antioxidant"], "xaxis": "x", "y": [112, 32, 28, 5, 3, 2, 1, 1, 1, 1], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %% [markdown]
# #Desafio 2
# ---

# %%
dados_combinados['eh_controle'] = (dados_combinados['tratamento'] == 'com_controle')
dados_combinados
# Out:
#                  id    tratamento  tempo  ... n_moa ativo_moa  eh_controle
# 0      id_000644bb2     com_droga     24  ...   5.0      True        False
# 1      id_000779bfc     com_droga     72  ...   0.0     False        False
# 2      id_000a6266a     com_droga     48  ...  11.0      True        False
# 3      id_0015fd391     com_droga     48  ...   0.0     False        False
# 4      id_001626bd3     com_droga     72  ...   5.0      True        False
# ...             ...           ...    ...  ...   ...       ...          ...
# 23809  id_fffb1ceed     com_droga     24  ...   5.0      True        False
# 23810  id_fffb70c0c     com_droga     24  ...   5.0      True        False
# 23811  id_fffc1c3f4  com_controle     48  ...   0.0     False         True
# 23812  id_fffcb9e7c     com_droga     24  ...   5.0      True        False
# 23813  id_ffffdd77b     com_droga     72  ...   0.0     False        False
#
# [23814 rows x 880 columns]

# %% [markdown]
# #Desafio 3
# ---

# %%
dados_combinados['24h'] = (dados_combinados['tempo'] == 24)
dados_combinados['48h'] = (dados_combinados['tempo'] == 48)
dados_combinados['72h'] = (dados_combinados['tempo'] == 72)
dados_combinados
# Out:
#                  id    tratamento  tempo dose  ... eh_controle    24h    48h    72h
# 0      id_000644bb2     com_droga     24   D1  ...       False   True  False  False
# 1      id_000779bfc     com_droga     72   D1  ...       False  False  False   True
# 2      id_000a6266a     com_droga     48   D1  ...       False  False   True  False
# 3      id_0015fd391     com_droga     48   D1  ...       False  False   True  False
# 4      id_001626bd3     com_droga     72   D2  ...       False  False  False   True
# ...             ...           ...    ...  ...  ...         ...    ...    ...    ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...       False   True  False  False
# 23810  id_fffb70c0c     com_droga     24   D2  ...       False   True  False  False
# 23811  id_fffc1c3f4  com_controle     48   D2  ...        True  False   True  False
# 23812  id_fffcb9e7c     com_droga     24   D1  ...       False   True  False  False
# 23813  id_ffffdd77b     com_droga     72   D1  ...       False  False  False   True
#
# [23814 rows x 883 columns]

# %% [markdown]
# #Desafio 4
# ---
# Resumindo:
# concatenate(concat): irá concatenar dois dataFrames
# obedecendo um conjunto de regras para essa concatenação. sejam elas a respeito do eixo em que as tabelas seram concatenadas, seja a forma como a função irá lidar com as informações cruzadas em ambos dataFrames(index por exemplo).
# ex(aula3):***corrgc0_50 = pd.concat([g200_249,c0_50], axis=1))***
#   O Merge: irá unir datFrames utilizando uma informação comum para vínculo, criando uma visualização com a junção de tabelas em que registros repetidos são ignorados e a visualização das informções é organizada de acordo com o vículo pré-estabelecido.
#   ex: ***dados_combinados = pd.merge(dados, dados_resultados[['id','n_moa', 'ativo_moa']], on='id')***
# O Join: possui um comportmento semelhante ao merge seguindo uma lógica semelhante à função join da liguagem SQL de banco de dados e da mesma forma que o merge ele junta tabelas utilizando um vínculo, e também critérios da teoria de conjuntos com união ou interseção.

# %% [markdown]
# #Desafio 5
# ---

# %%
print(dados_combinados['n_moa'].unique())
dados_combinados['composto'].value_counts() #escolhemos o segundo composto que mais aparece já que o primeiro se trata da classe de controle
# Out:
# [13.  0. 27. 20. 34. 41. 55.]
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# ed64cad3a       1
# 0dedfb162       1
# ae2afcf9d       1
# bc21046fe       1
# 6e418401d       1
# Name: composto, Length: 3289, dtype: int64

# %%
dados_Composto = dados_combinados.loc[dados_combinados.composto=='87d714366']
dados_Composto2 = dados_combinados.loc[dados_combinados.composto=='9f80f3f77']
dados_Controle = dados_combinados.loc[dados_combinados.composto=='cacb2b860']
#dados_Controle

# %%
print(dados_Composto['n_moa'].unique())
print(dados_Composto2['n_moa'].unique())
print(dados_Controle['n_moa'].unique())
# Out:
# [20.]
# [13.]
# [0.]

# %%
print("Escolha um gene(0 a 771):")
try: n = (int)(input())
except:
  while n not in range(772):
    print("Escolha um gene(0 a 771):")
    n = (int)(input())

gene = "g"+ str(n)
dados_Composto_Controle = pd.concat([dados_Composto,dados_Controle],axis=0)
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
sns.boxplot(data = dados_Composto_Controle, y= gene, x='dose', hue='composto')
plt.subplot(1,2,2)
sns.boxplot(data = dados_Composto_Controle, y= gene, x='tempo', hue='composto')
# Out:
# Escolha um gene(0 a 771):
# 0

# %%
dados_Composto_Controle = pd.concat([dados_Composto,dados_Controle],axis=0)
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
sns.barplot(data = dados_Composto_Controle, y= gene, x='dose', hue='composto')
plt.subplot(1,2,2)
sns.barplot(data = dados_Composto_Controle, y= gene, x='tempo', hue='composto')

# %%
plt.figure(figsize=(8,6))
sns.barplot(data = dados_Composto_Controle, y= gene, x='ativo_moa', hue='composto')

# %%
plt.figure(figsize=(20,8))
hg0 = sns.histplot(data=dados_Composto_Controle,x=gene,color='red',bins=120,hue='composto')
hg0.set_title('Gene '+str(gene),fontdict={'fontsize':25})
hg0.tick_params(labelsize=20)
hg0.set_ylabel("Valores",fontdict={'fontsize':25})
hg0.set_xlabel(str(gene),fontdict={'fontsize':25})
sns.set_theme(font='Calibri')

# %%
plt.figure(figsize=(18,12))
plt.subplot(2,2,1)
sns.scatterplot(x=gene, y='n_moa', data=dados_Composto_Controle,hue='tempo')
plt.subplot(2,2,2)
sns.scatterplot(x=gene, y='n_moa', data=dados_Composto_Controle,hue='dose')
plt.subplot(2,2,3)
sns.scatterplot(x=gene, y='n_moa', data=dados_Composto_Controle,hue='composto')
#aparentemente o número de MOA não altera independente da variável tempo nem dose para esse composto

# %% [markdown]
# #Desafio 6
# ---

# %%
compostos = list(dados_combinados['composto'].value_counts().keys())
composto_muda = []
for n in compostos:
  dados_CompostoAtual = dados_combinados.loc[dados_combinados.composto==n]
  l = len(dados_CompostoAtual['n_moa'].unique())
  if(l==1):
    composto_muda.append(n)
print(composto_muda)
#nenhum composto apresenta mudança no número de MOA no decorrer da tabela caso contrário o UNIQUE apresentaria mais de um valor
# Out:
# ['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee', 'd08af5d4b', '292ab2c28', 'd50f18348', 'd1b47f29d', '67c879e79', '83a9ea167', 'd488d031d', '52d1e6f43', '5d9bb0ebe', '11f66c124', '30aa2f709', '6b8b675cc', '1a52478dc', 'a7c2673c1', '8c91d6909', 'b3031b373', '02ae89796', '20a3c3f90', '1d6d22a71', 'aa7b9f4cc', '1d4c91026', 'ab50adc64', 'bb3b7c7d5', 'f92989f8d', '2f5b9b3bd', 'af12e2904', '10dbb5b2a', '3ff075492', '03b09563c', 'fd4387eac', '5a518a0f0', '1d3112471', '0b1ed98a0', 'd149a15f5', 'a44e72ca3', '88c37c66a', '61155e673', 'e0cd5c091', 'd3ff26fc7', '7473b8828', '754486b37', 'b6dc8d1e1', '1b09b35f0', '8c7f86626', '5fe9c41db', '1b20d8d8d', 'afd0dbace', 'e57f7453e', '4a65421e6', 'ae0c59f9b', '8bfccb68b', '20c9d8e5c', 'de7b27dbc', 'f4f4771c9', '6def270ae', '3df6fc891', '5aa46f542', 'd632db159', 'bda439de9', '043fedc3f', 'c3273cd04', '34cb34a74', 'e23fb6c1c', '8ed81dd51', '50e38451f', '00321ea80', '46befd494', '0249e20c4', '55e4096d8', 'e651aad68', '96c2fddf7', '9aff06a16', '2688e0167', '404e713a8', 'd73b6a4a2', 'e78c48114', '3a383db4a', '1344cf491', '82da03539', '95a5b4f7e', '68869f4e9', 'a3066427d', 'e572e62e2', '4ddf83a79', '39cc616d2', '93303298e', '3610da8fc', 'fe8625cad', '824a6c1ca', '24a3fbf37', '6b2d73b7d', 'e66896455', 'b30c11496', '357bf33db', '24c787f29', '472eaa5fd', '91b11acc4', 'ef8b7fe07', '0994324f7', 'f2cd513d6', '5c68cde71', '9e25474f1', '1df2f9781', '8a4370a9b', '42446ee76', 'd74175a91', 'a2a054566', '26574c800', '7db360ff6', '18c37e601', 'e53bd9396', 'b2bce570f', '3859c44f3', '7d1d72083', '6a1616f45', 'ea8db5dd6', '4b3c59823', '4b138d0a8', '5735a3e0f', '2a4c67eba', '649d95014', '908482858', 'c106a3f18', '853dca78a', '721fbbc54', 'eb1abad45', '9900aeef2', 'e5922d23c', 'e160a2b00', '9b964b696', '3a02fdb9b', '4b8caf802', '2266410ca', '872bc007e', '5ec98e006', 'bb9ea924c', '9cbacb6de', '6324b63b6', 'fc4cd4585', '31d5cf076', '9f31b00f7', 'eef00a2d4', '3ed7ea58f', '014d175d7', 'bc8f3b60e', '5387c8eaa', '9ef936a40', '12fd34362', 'c27e6af6f', 'b266bfb86', '14b9e5384', '991dccfc4', '1196f6507', 'e3a88c3f3', '78a9ee6c5', '6a7fd5fd2', '399cbeb3e', '57f7c6a5c', '98d258152', '8e62620d4', 'ca8854531', 'bbec32b06', 'fa69a1fc0', '925488749', '3f8e9f8cf', 'df9c4c6af', '8abbf7b55', 'a1f4f1154', 'e20a1c258', 'c63a7ee15', '825e3a43c', 'b8bffd104', '28bdee607', '3b1b7319a', 'cbc278c8c', '7ab43c75d', '146ba19d5', '31cdc0d4a', 'ea8ed8051', '4b7a7d212', '67b8f0a99', 'db657e8ac', '9d1c9eb50', '26f1351c1', '94ce06893', '03b81e62e', 'c89f8f935', 'd01936d7e', '3cda750b5', '29ea347ea', '57ccb23c1', 'b1795fcb0', '3628040f9', '0957d670d', '285fbb0b0', 'cedb6c4a8', '035a6a762', 'af22cc3d8', 'be3cd78c2', '28879e19e', 'b96fb04fa', '816767bf6', '244ef8123', '2f2e37eda', '3710f60fa', '07bd8c42c', 'ff551f3a3', 'aeda2a606', 'efd859187', 'd032e3d51', 'ab5979bc0', '0dcd1acb9', '3e677daea', 'f9d0d8f63', '701fd55ef', '47bcdff9d', '519d5133b', '3daf3ab5b', '9288cf822', 'c6e681fa2', 'd631fcc6c', 'd6cf25434', '1b1a45a6b', '538ff01f5', '6540c0b79', '0f2ec8169', '56e484932', '18bb41b2c', 'c4fd19474', '2abc6c21e', '0a5a4f458', 'ad84986d3', 'c46beda84', 'f228f319c', 'fbd77dbb9', '2d3cb8f30', '9898cba0d', 'b16c06e60', '0393401cc', 'abe5d0dcc', 'de8fa84b4', '299460cf3', 'f2b81ca2e', 'dd313d89e', 'c8763b2d3', '5ac378d8a', 'a2f3f1f63', 'abe3d3a3f', 'c7ecff8b4', '1c3236de2', '3fcf6c45a', '8693b40e8', '3f2f378cf', '3c195fc5b', '8ab72a1bc', 'bd9cf521f', '702238187', 'd38a2d3ef', '989a4f93d', '847fbc822', '0cc68ee7c', 'eacb563b3', 'd9f666bcd', '8e438ce43', '3b2bdd584', 'f007bd74e', '6f430a5f0', '6895c50ed', 'bd30d81ce', 'adabf11d3', '79f6039a3', '65d7f344a', '24ac0214f', '87705adb2', '8229f1030', 'f63b5512f', '123bd9005', 'e610a38d4', 'ec02e96a8', '728eb0f63', '508e74297', 'f48d611be', '481a0c086', '23b0c6122', '15da4702d', '3c8c824ff', 'bcaae6660', 'c9bc74fb3', 'a13f301e0', '260a804ec', '2f1db8c6c', '5b132e580', 'ee806f8a1', 'dd4b64a59', '5e6359c7c', 'b439cd83a', 'adfbd607a', '70cd13738', '7f69271a1', '6b27abb86', '6dfda028e', '6274c8c1f', '6ef24fb ...

# %% [markdown]
# #Desafio 7
# ---

# %%
MOA_diferentes = pd.merge(dados[['id','composto']], dados_resultados, on='id')
MOA_diferentes
# Out:
#                  id   composto  ...  n_moa  ativo_moa
# 0      id_000644bb2  b68db1d53  ...   13.0       True
# 1      id_000779bfc  df89a8e5a  ...    0.0      False
# 2      id_000a6266a  18bb41b2c  ...   27.0       True
# 3      id_0015fd391  8c7f86626  ...    0.0      False
# 4      id_001626bd3  7cbed3131  ...   13.0       True
# ...             ...        ...  ...    ...        ...
# 23809  id_fffb1ceed  df1d0a5a1  ...   13.0       True
# 23810  id_fffb70c0c  ecf3b6b74  ...   13.0       True
# 23811  id_fffc1c3f4  cacb2b860  ...    0.0      False
# 23812  id_fffcb9e7c  8b87a7a83  ...   13.0       True
# 23813  id_ffffdd77b  972f41291  ...    0.0      False
#
# [23814 rows x 210 columns]

# %%
compostos = list(MOA_diferentes['composto'].value_counts().keys())
composto_muda = []
for n in compostos:
  dados_CompostoAtual = MOA_diferentes.loc[MOA_diferentes.composto==n]
  for j in list(dados_CompostoAtual.drop('id',axis=1).columns):
    l = len(dados_CompostoAtual[j].unique())
    if(l>1):
      composto_muda.append(n)
print(composto_muda)
#Separamos por composto e analisamos cada coluna de MOA procurando por mudanças de valor
#como não encontramos mudanças concluimos que não há MOA's diferentes para o mesmo composto
# Out:
# []

# %% [markdown]
# #Desafio 8
# ---
# Por hoje foi possível verificar o comportamento de um composto sobre o valor de um gene quando comparado à população de controle. Visualizamos como o composto modifica a distribuição dos valores do gene e também como o composto se comporta de acordo com a dose e o tempo. Para generalizar a análise ao gosto de quem quiser visualizar, no desafio 5 há uma pequena interação para escolha do gene sobre o qual se deseja visualizar. Foi aprendido também que os MOA possívelmente são característicos de cada composto já que para o mesmo composto não há MOA's diferentes independete das configurações de tempo e dosagem, por mais que esses fatores possam interferir no valor de um gene especifico.
